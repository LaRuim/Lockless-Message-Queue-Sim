# %%
import matplotlib.pyplot as plt
from statistics import *
f = open("benchmarks.txt", "r")
raw_data = f.readlines()
data = [float(x[:-2]) for x in raw_data]
x = list(x for x in range(1,101))

# %%
plt.xlabel('Trial No.')
plt.ylabel('Time taken for 15 tasks')
plt.title('Lock-free')
plt.plot(x, data)

# %%
mean(data)
# Out:
# 11.806045

# %%
f = open("../test5/benchmarks.txt", "r")
raw_data = f.readlines()
data = [float(x[:-2]) for x in raw_data]
x = list(x for x in range(1,101))

# %%
plt.xlabel('Trial No.')
plt.ylabel('Time taken for 15 tasks')
plt.title('Using locks')
plt.plot(x, data)

# %%
mean(data)
# Out:
# 13.61049
